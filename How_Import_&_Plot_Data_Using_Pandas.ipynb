# %% [markdown]
# <a href="https://colab.research.google.com/github/tahirkhalid/Google-Capston-CaseStudy/blob/main/How_Import_%26_Plot_Data_Using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
df=pandas.read_csv("/content/drive/MyDrive/DataSets/Moving_Averages_Data.csv")

# %%
df["Dates"]=pandas.to_datetime(df['Dates'],format='%Y-%m-%d')

# %%
df
# Out:
#        Dates  Price
# 0 2025-03-01   4300
# 1 2025-03-02    300
# 2 2025-03-03   3100
# 3 2025-03-04    100
# 4 2025-03-05   3900
# 5 2025-03-06   1800
# 6 2025-03-07   1500
# 7 2025-03-08   4900
# 8 2025-03-09    600
# 9 2025-03-10   1400

# %%
df.plot.line(x='Dates',y='Price')
# Out:
# <Axes: xlabel='Dates'>
